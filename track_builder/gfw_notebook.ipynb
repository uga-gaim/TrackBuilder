# %%
import pandas as pd
import plotly.express as px
from conversion import points_to_smooth_lines

# %%
df_archived = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort-v1-v2-archived/mmsi-daily-csvs-10-v2-2019/2019-01-01.csv", sep=',')

# %%
df_archived.head()
# Out:
#          date  cell_ll_lat  cell_ll_lon       mmsi   hours  fishing_hours
# 0  2019-01-01          0.0       -105.6  224900000  0.2036            0.0
# 1  2019-01-01          0.0       -105.3  224900000  0.0205            0.0
# 2  2019-01-01          0.0       -105.5  224900000  0.9008            0.0
# 3  2019-01-01          0.0       -105.4  224900000  0.8638            0.0
# 4  2019-01-01          0.0         -0.3  228071900  0.7969            0.0

# %%
df_feb_01 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-01.csv", sep=',')
df_feb_02 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-02.csv", sep=',')
df_feb_03 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-03.csv", sep=',')
df_feb_04 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-04.csv", sep=',')
df_feb_05 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-05.csv", sep=',')
df_feb_06 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-06.csv", sep=',')
df_feb_07 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-07.csv", sep=',')
df_feb_08 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-08.csv", sep=',')
df_feb_09 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-09.csv", sep=',')
df_feb_10 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-10.csv", sep=',')
df_feb_11 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-11.csv", sep=',')
df_feb_12 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-12.csv", sep=',')
df_feb_13 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-13.csv", sep=',')
df_feb_14 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-14.csv", sep=',')
df_feb_15 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-15.csv", sep=',')
df_feb_16 = pd.read_csv("/Users/willponczak/Desktop/QC2025/data/gfw/ais-apparent-fishing-effort/mmsi-daily-csvs-10-v3-2019/mmsi-daily-csvs-10-v3-2019-01-16.csv", sep=',')

# %%
df.head()
# Out:
#          date  cell_ll_lat  cell_ll_lon       mmsi   hours  fishing_hours
# 0  2019-01-01        -74.6       -106.5  440347000  0.8363         0.5983
# 1  2019-01-01        -74.6       -106.3  440347000  0.2288         0.0000
# 2  2019-01-01        -74.6       -105.7  440347000  0.2599         0.2599
# 3  2019-01-01        -74.6       -106.4  440347000  0.3008         0.0000
# 4  2019-01-01        -74.6       -106.6  440347000  1.8158         1.5694

# %%
df_feb = pd.concat([df_feb_01, df_feb_02, df_feb_03, df_feb_04, df_feb_05, df_feb_06, df_feb_07, df_feb_08, df_feb_09, df_feb_10, df_feb_11, df_feb_12, df_feb_13, df_feb_14, df_feb_15, df_feb_16]
)

# %%
df_feb.shape
# Out:
# (2071373, 6)

# %%
df_feb_match_query = df_feb[
    (df_feb['cell_ll_lon'] >= -24.425) &
    (df_feb['cell_ll_lon'] <= -18.510) &
    (df_feb['cell_ll_lat'] >= 63.541) &
    (df_feb['cell_ll_lat'] <= 65.007)
]

# %%
df_feb_match_query.shape
# Out:
# (6323, 6)

# %%
# Convert MMSI to string so it's treated as a category
df_feb_match_query['mmsi'] = df_feb_match_query['mmsi'].astype(str)

fig = px.scatter_mapbox(
    df_feb_match_query,
    lat='cell_ll_lat',
    lon='cell_ll_lon',
    hover_name='mmsi',
    height=600,
    mapbox_style='open-street-map',
    color='mmsi'
)

fig.show()
# Out:
# /var/folders/9d/bphw52wd7fngbyw4fdd0280h0000gp/T/ipykernel_5088/899560237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feb_match_query['mmsi'] = df_feb_match_query['mmsi'].astype(str)

# %%
# E.g. sort by DataFrame index
df_feb_match_query_sorted = df_feb_match_query.sort_index()

fig = px.line_mapbox(
    df_feb_match_query_sorted,
    lat='cell_ll_lat',
    lon='cell_ll_lon',
    color='mmsi',
    line_group='mmsi',
    hover_name='mmsi',
    height=600,
    mapbox_style='open-street-map'
)

fig.show()

# %%
df_feb_match_query_sorted_1mmsi = df_feb_match_query_sorted[(df_feb_match_query_sorted['mmsi'] == 251164000)]

# %%
df_feb_match_query_sorted_1mmsi.shape
# Out:
# (84, 6)

# %%
df_feb_match_query_sorted_1mmsi = points_to_smooth_lines(df_feb_match_query_sorted_1mmsi)

# %%
df_feb_match_query_sorted_1mmsi.reset_index()
# Out:
#         mmsi  start_date    end_date    hours  fishing_hours  n_pixels  \
# 0  251164000  2019-01-03  2019-01-14  51.2755            0.0        84
#
#                                             geometry
# 0  LINESTRING (-23.6 64, -23.6 64, -23.6 64, -23....

# %%
df_feb_match_query_sorted_1mmsi
# Out:
#            start_date    end_date    hours  fishing_hours  n_pixels  \
# mmsi
# 251164000  2019-01-03  2019-01-14  51.2755            0.0        84
#
#                                                     geometry
# mmsi
# 251164000  LINESTRING (-23.6 64, -23.6 64, -23.6 64, -23....

# %%
fig = px.line_geo(
    df_feb_match_query_sorted_1mmsi.reset_index(),
    lat='cell_ll_lat',
    lon='cell_ll_lon',
    color='mmsi',
    line_group='mmsi',
    hover_name='mmsi',
    height=600,
    mapbox_style='open-street-map'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 fig = px.line_geo(
#       2     df_feb_match_query_sorted_1mmsi.reset_index(),
#       3     lat='cell_ll_lat',
#       4     lon='cell_ll_lon',
#       5     color='mmsi',
#       6     line_group='mmsi',
#       7     hover_name='mmsi',
#       8     height=600,
#       9     mapbox_style='open-street-map'
#      10 )
#      12 fig.show()
#
# TypeError: line_geo() got an unexpected keyword argument 'mapbox_style'

# %%
import plotly.graph_objects as go

fig = go.Figure()

for mmsi, group in df_feb_match_query.groupby('mmsi'):
    group_sorted = group.sort_values('hours')
    fig.add_trace(go.Scattermapbox(
        lat=group_sorted['cell_ll_lat'],
        lon=group_sorted['cell_ll_lon'],
        mode='lines+markers',
        name=str(mmsi),
        hoverinfo='text',
        text=[
            f"MMSI: {mmsi}<br>Hours: {h}"
            for h in group_sorted['hours']
        ]
    ))

fig.update_layout(
    mapbox_style='open-street-map',
    height=600
)

fig.show()

# %%
# Find rows matching the harbor cell
df_harbor = df_feb_match_query[
    (df_feb_match_query['cell_ll_lat'] == 63.000) &
    (df_feb_match_query['cell_ll_lon'] == -22.000)
]

# Get MMSIs that pass through that grid cell
mmsi_in_harbor_cell = df_harbor['mmsi'].unique()

# Filter your DataFrame to only those MMSIs
df_filtered = df_feb_match_query[
    df_feb_match_query['mmsi'].isin(mmsi_in_harbor_cell)
]

# %%
df_filtered.shape
# Out:
# (0, 6)

# %%
# Sort by hours for correct track lines
df_filtered_sorted = df_filtered.sort_values(['mmsi', 'hours'])

fig = px.line_mapbox(
    df_filtered_sorted,
    lat='cell_ll_lat',
    lon='cell_ll_lon',
    color='mmsi',
    line_group='mmsi',
    hover_name='mmsi',
    height=600,
    mapbox_style='open-street-map'
)

fig.show()

# %%
import plotly.express as px

# Filter your DataFrame to this MMSI
df_single_ship = df_feb_match_query[
    df_feb_match_query['mmsi'] == 251789110
]

# Plot points only
fig = px.scatter_mapbox(
    df_single_ship,
    lat='cell_ll_lat',
    lon='cell_ll_lon',
    hover_name='mmsi',
    height=600,
    mapbox_style='open-street-map'
)

fig.show()
